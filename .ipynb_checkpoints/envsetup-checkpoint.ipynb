# %%
# %%bash
# conda create --name rwe-env --override-channels -c https://repo.anaconda.com/pkgs/snowflake python=3.8 numpy pandas snowflake-snowpark-python ipykernel
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/rwe-env
#
#   added / updated specs:
#     - ipykernel
#     - numpy
#     - pandas
#     - python=3.8
#     - snowflake-snowpark-python
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |             main           3 KB  https://repo.anaconda.com/pkgs/snowflake
#     _openmp_mutex-5.1          |            1_gnu          20 KB  https://repo.anaconda.com/pkgs/snowflake
#     asn1crypto-1.5.1           |   py38h06a4308_0         162 KB  https://repo.anaconda.com/pkgs/snowflake
#     asttokens-2.0.5            |     pyhd3eb1b0_0          21 KB  https://repo.anaconda.com/pkgs/snowflake
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB  https://repo.anaconda.com/pkgs/snowflake
# ...

# %%
import snowflake.connector
import sys
from snowflake.snowpark import Session
print("Snowflake Imported")
# Out:
# Snowflake Imported

# %%
INFOS = {
    'user':            "sukriti.poddar@sanofi.com",
    'authenticator':   "externalbrowser",
    'account':         "sanofi-emea_df_rwd",
    'database':        "DF_RWD_PROD",
    'warehouse':      "DF_RWD_PROD_WH_PRJ_T1_PREDICTION",
    'role':            "DF_RWD_PROD_PRJ_T1_PREDICTION_DEVELOPER",
         }

snowpark = Session.builder.configs(INFOS).create()
# Out:
# Initiating login request with your identity provider. A browser window should have opened for you to complete the login. If you can't see it, check existing browser windows, or your OS settings. Press CTRL+C to abort and try again...
# ...

# %%
DF=snowpark.table("RWD_OPTUM_CLINFORMATICS_DOD_PSA.MEDICAL_DIAGNOSIS")

# %%
#Excelfile_table = new_session.table('PRJ_REZUROCK_HCRU_PSA."Excel_FIle"')

# %%
if not hasattr(display,"__extended__"):
    import pandas as pd
    original_dbx_display = display
    from snowflake.snowpark import DataFrame
    def snowflake_dataframe_to_pd_safe(df):
        rows_limit = 5
        try:
            count = df.count()
            if count == 0:
                df = pd.DataFrame()
            elif count == 1:
                pandas_df = pd.DataFrame.from_records([x.as_dict() for x in r])
                return pandas_df
            elif count > rows_limit:
                print(f"There are {count} rows. Showing only {rows_limit} ")
                return df.limit(rows_limit).to_pandas()
            else:
                return df.to_pandas()
        except Exception as ex:
            return str(ex)
    def display(x):
        if isinstance(x,DataFrame):
            original_dbx_display(snowflake_dataframe_to_pd_safe(x))
        else:
            original_dbx_display(x)
    setattr(display,"__extended__",True)

# %%
display(DF)
# Out:
# There are 11765754473 rows. Showing only 5
#          PATID   PAT_PLANID       CLMID   DIAG DIAG_POSITION ICD_FLAG LOC_CD  \
# 0  33055416025  53136490689   190384810   D631            02       10      2
# 1  33055416025  53136490689   190384810   N183            01       10      2
# 2  33055416025  53136490689  2447624368   D649            03       10      1
# 3  33055416025  53136490689  2447624368  E8310            02       10      1
# 4  33055416025  53136490689  2447624368  R7989            01       10      1
#
#   POA EXTRACT_YM VERSION      FST_DT FILE_MNTH    LOAD_TS UPDATE_TS
# 0   0     202309     9.0  2017-12-07    202312 2024-02-05       NaT
# 1   0     202309     9.0  2017-12-07    202312 2024-02-05       NaT
# 2   1     202309     9.0  2017-10-26    202312 2024-02-05       NaT
# 3   1     202309     9.0  2017-10-26    202312 2024-02-05       NaT
# 4   1     202309     9.0  2017-10-26    202312 2024-02-05       NaT

# %%
#pip install "snowflake-snowpark-python[pandas]"
# Out:
# Looking in indexes: https://PS112203%40sanofi.com:****@sanofi.jfrog.io/artifactory/api/pypi/pypi-one_ai-virtual/simple, https://pypi.org/simple
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 35.1 MB/s eta 0:00:0000:01:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import snowflake.snowpark
from snowflake.snowpark import functions as F
from snowflake.snowpark.window import Window as W
from snowflake.snowpark.types import IntegerType, BooleanType, DateType, StringType, FloatType
from snowflake.snowpark.functions import expr
from snowflake.snowpark.functions import lit, when, concat, trim, col, desc, to_date, daydiff, year, date_add, month, date_sub, datediff, to_timestamp,date_format
from snowflake.snowpark.functions import countDistinct, regexp_extract, regexp_replace, udf, rank
import getpass
from snowflake.snowpark.functions import expr
from snowflake.snowpark.functions import row_number
from snowflake.snowpark import Row
from snowflake.snowpark.functions import *
from snowflake.snowpark.functions import translate
import pandas
from pathlib import Path
import pandas as pd
import numpy as np

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://PS112203%40sanofi.com:****@sanofi.jfrog.io/artifactory/api/pypi/pypi-one_ai-virtual/simple, https://pypi.org/simple
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.9 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
